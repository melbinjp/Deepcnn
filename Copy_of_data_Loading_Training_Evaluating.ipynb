# %% [markdown]
# <a href="https://colab.research.google.com/github/melbinjp/Deepcnn/blob/main/Copy_of_data_Loading_Training_Evaluating.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Code on (github.com/mr7495/covid19)

# %%
# !nvidia-smi #show the allocated GPU
# Out:
# Wed May 25 13:58:31 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   61C    P8    11W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
#Connect your Google Drive 
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#upgrade and install essential libraries
# !pip install tensorflow
# !pip install keras #--upgrade
# !pip install zipfile36
# !pip install pydicom
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.7/dist-packages (2.8.0+zzzcolab20220506162203)
# Requirement already satisfied: flatbuffers>=1.12 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (2.0)
# Requirement already satisfied: absl-py>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (1.0.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (3.1.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from tensorflow) (57.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (4.2.0)
# Requirement already satisfied: tensorboard<2.9,>=2.8 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (2.8.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (1.46.1)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (0.26.0)
# Requirement already satisfied: libclang>=9.0.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (14.0.1)
# Requirement already satisfied: gast>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (0.5.3)
# Collecting tf-estimator-nightly==2.8.0.dev2021122109
#   Downloading tf_estimator_nightly-2.8.0.dev2021122109-py2.py3-none-any.whl (462 kB)
#      |████████████████████████████████| 462 kB 8.5 MB/s
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (1.15.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (1.1.0)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (1.21.6)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (1.14.1)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (1.1.2)
# Requirement already satisfied: protobuf>=3.9.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (3.17.3)
# Requirement already satisfied: keras<2.9,>=2.8.0rc0 in /usr/local/lib/python3.7/dist-packages (from tensorflow) (2.8.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.7/dist-packages (from astunparse>=1.6.0->tensorflow) (0.37.1)
# Requirement already satisfied: cached-property in /usr/local/lib/python3.7/dist-packages (from h5py>=2.9.0->tensorflow) (1.5.2)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow) (1.0.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow) (1.8.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow) (3.3.7)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow) (0.4.6)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow) (0.6.1)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow) (2.23.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow) (1.35.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow) (4.8)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow) (0.2.8)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow) (4.2.4)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.9,>=2.8->tensorflow) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.7/dist-packages (from markdown>=2.6.8->tensorboard<2.9,>=2.8->tensorflow) (4.11.3)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.9,>=2.8->tensorflow) (3.8.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow) (0.4.8)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow) (2022.5.18.1)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow) (1.24.3)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.9,>=2.8->tensorflow) (3.2.0)
# Installing collected packages: tf-estimator-nightly
# Successfully installed tf-estimator-nightly-2.8.0.dev2021122109
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: keras in /usr/local/lib/python3.7/dist-packages (2.8.0)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting zipfile36
#   Downloading zipfile36-0.1.3-py3-none-any.whl (20 kB)
# Installing collected packages: zipfile36
# Successfully installed zipfile36-0.1.3
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pydicom
#   Downloading pydicom-2.3.0-py3-none-any.whl (2.0 MB)
#      |████████████████████████████████| 2.0 MB 8.0 MB/s
# Installing collected packages: pydicom
# Successfully installed pydicom-2.3.0

# %%
import keras
import numpy as np
import cv2
import os
import random
import shutil
import pandas as pd
import csv
import pydicom as dicom
import zipfile
from keras import optimizers
from keras.models import Sequential,Model
from keras.layers import Dropout, Flatten, Dense,Input
from keras.applications.resnet_v2 import ResNet50V2
from keras.applications.xception import Xception
from keras.callbacks import ModelCheckpoint
from keras.applications.imagenet_utils import preprocess_input
from keras import backend as K
from keras.preprocessing.image import ImageDataGenerator
from keras.initializers import RandomNormal

# %%
# This is a link to kaggle dataset. If you have downloaded it already, save it as kaggle.zip in the current directory.
# If the link expired, get the new link from https://www.kaggle.com/c/rsna-pneumonia-detection-challenge/data

# !wget -cO - 'https://storage.googleapis.com/kaggle-competitions-data/kaggle-v2/10338/862042/bundle/archive.zip?GoogleAccessId=web-data@kaggle-161607.iam.gserviceaccount.com&Expires=1653744713&Signature=Durxt1xtU%2BV1RFrAtmckBuilzgugNMQPYVorE%2BDKAo%2BvjypiVJiTQP3GSVJZzRqnbU7ooGOxYZkHoaAUQjsukSJZjJs%2F%2BeyS1hbPy7bkIMls9aeKZRIKPhmdJfJIdZVECXJ4wt0wXQjE7IJJvUGc3onNALe1n%2BmyVaOw17%2FqCqDIc39OirpWLMTLjsrrVuwStiKSXkCgHqFdnF4vQUOHgsCDCXxKB378rDrWGqFDgZPKMVpzH9EHq9sekGIO0dtW%2BvHQXeGfPCTuPsiAGe3sD5qRKkGwarxtJDwQDe8mddlA5umV2336UWHUa0ou61WomkW9gJjetb1jDMq62DA4Qw%3D%3D&response-content-disposition=attachment%3B+filename%3Drsna-pneumonia-detection-challenge.zip' > kaggle.zip
# Out:
# --2022-05-25 13:59:07--  https://storage.googleapis.com/kaggle-competitions-data/kaggle-v2/10338/862042/bundle/archive.zip?GoogleAccessId=web-data@kaggle-161607.iam.gserviceaccount.com&Expires=1653744713&Signature=Durxt1xtU%2BV1RFrAtmckBuilzgugNMQPYVorE%2BDKAo%2BvjypiVJiTQP3GSVJZzRqnbU7ooGOxYZkHoaAUQjsukSJZjJs%2F%2BeyS1hbPy7bkIMls9aeKZRIKPhmdJfJIdZVECXJ4wt0wXQjE7IJJvUGc3onNALe1n%2BmyVaOw17%2FqCqDIc39OirpWLMTLjsrrVuwStiKSXkCgHqFdnF4vQUOHgsCDCXxKB378rDrWGqFDgZPKMVpzH9EHq9sekGIO0dtW%2BvHQXeGfPCTuPsiAGe3sD5qRKkGwarxtJDwQDe8mddlA5umV2336UWHUa0ou61WomkW9gJjetb1jDMq62DA4Qw%3D%3D&response-content-disposition=attachment%3B+filename%3Drsna-pneumonia-detection-challenge.zip
# Resolving storage.googleapis.com (storage.googleapis.com)... 173.194.202.128, 74.125.20.128, 74.125.197.128, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|173.194.202.128|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3932287530 (3.7G) [application/zip]
# Saving to: ‘STDOUT’
#
# -                   100%[===================>]   3.66G   127MB/s    in 28s
#
# 2022-05-25 13:59:35 (134 MB/s) - written to stdout [3932287530/3932287530]

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#Get the zip file I have shared, that contains the covid-chestxray-dataset images until 12 April
# Through the link below get the shared zip file and add it to your drive:
# https://drive.google.com/file/d/1Bwn4vTQUUB0tHK5aHh--Rk6eOxs2jg3q/view?usp=sharing
archive = zipfile.ZipFile('kaggle.zip') #Extract Kaggle Dataset
for file in archive.namelist():
     archive.extract(file, './All')
archive = zipfile.ZipFile('drive/My Drive/covid-chestxray-dataset.zip') #Extract covid-chestxray-Dataset
for file in archive.namelist():
     archive.extract(file, './covid-chestxray-dataset')

# %%
fold_num=1 #Select Fold Number

# %%
try:
  os.mkdir('All/All')
except:
  pass

# %%
# !git clone https://github.com/mr7495/covid19 #connect to our repository on GitHub
# Out:
# Cloning into 'covid19'...
# remote: Enumerating objects: 421, done.
# remote: Counting objects: 100% (10/10), done.
# remote: Compressing objects: 100% (10/10), done.
# remote: Total 421 (delta 2), reused 0 (delta 0), pack-reused 411
# Receiving objects: 100% (421/421), 6.56 MiB | 16.74 MiB/s, done.
# Resolving deltas: 100% (223/223), done.

# %%
#Warning: Our prepared All.csv & train1.csv to train8.csv in each fold, are based on the covid-chestxray-dataset until 12 April.
#If you have used https://drive.google.com/file/d/1Bwn4vTQUUB0tHK5aHh--Rk6eOxs2jg3q/view?usp=sharing link to get the covid-chestxray-dataset.zip file(like the cells above), you can use our prepared csv files
#But if you want to load the updated covid-chestxray-dataset, you must make some changes to the csvfiles.
shutil.copy('covid19/prepared_csv_files/All.csv','All')
for i in range(1,9): #Load the 8 training phases csv files of the indicated fold
  shutil.copy('covid19/prepared_csv_files/fold{}/train{}.csv'.format(fold_num,i),'.')
  globals()['train{}'.format(i)]=[]

# The code for creating All.csv and training.csv files is available on  covid19/dataset preparing.ipynb.

# %%
images=[]
for r,d,f in os.walk('All/stage_2_train_images'): #Read the name of the images in both datasets
  for file in f:
    images.append(os.path.join(r,file))
for r,d,f in os.walk('covid-chestxray-dataset/images'):
  for file in f:
   images.append(os.path.join(r,file))

# %%
csv_all=pd.read_csv('All/All.csv', nrows=None) #Read the CSV file that contains the names of the images with their labels.
for index, row in csv_all.iterrows(): #This loop reads the images, converts them to suitable format and saves them in the All directory
  if '.png' in row['filename']: #For creating the All.csv we have converted the kaggle dataset images to png format,
                                #but some of the images in the other dataset also are in the format of png, so we use try/except here to distinguish which dataset, the annotation in the CSV file belongs to.
    try:
      png_index=row['filename'].find('.png')
      last_name=row['filename'][:png_index]+'.dcm'
      ds = dicom.dcmread(os.path.join('All/stage_2_train_images',last_name))
      pixel_array_numpy = ds.pixel_array
      imgname = last_name[:-4]+'.png'
      cv2.imwrite(os.path.join('All/All', imgname), pixel_array_numpy)
    except:
      png_index=row['filename'].find('.png')
      img=cv2.imread(os.path.join('covid-chestxray-dataset/images',row['filename'][:png_index+4])) 
      gray=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
      cv2.imwrite(os.path.join('All/All', row['filename'][:png_index+4]), gray)  
  else:
    img=cv2.imread(os.path.join('covid-chestxray-dataset/images',row['filename']))
    gray=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
    cv2.imwrite(os.path.join('All/All', row['filename']), gray)

# %%
All=[] #Thie list that is readed from All.csv
all_train=[] #This list contains the training annotations
all_test=[]
with open('All/All.csv',newline='', mode='r') as csvfile: #Adding All.csv rows to All list
      csvreader = csv.reader(csvfile, delimiter=',', quotechar='"', quoting=csv.QUOTE_MINIMAL)
      for row in csvreader:
          All.append(row)
for i in range(1,9): #Adding training1.csv to training8.csv rows to All_train list. This 1 to 8 indicate the 8 training phases
  with open('train{}.csv'.format(i),newline='', mode='r') as csvfile:
      csvreader = csv.reader(csvfile, delimiter=',', quotechar='"', quoting=csv.QUOTE_MINIMAL)
      for row in csvreader:
        all_train.append(row)
with open('all_test.csv'.format(i),newline='', mode='w') as csvfile: #Add all the other images that do not belong to the training phases, to the test set
    csvwriter = csv.writer(csvfile, delimiter=',', quotechar='"', quoting=csv.QUOTE_MINIMAL)
    csvwriter.writerow(['filename','class'])
    for row in All:
      if row not in all_train:
        csvwriter.writerow(row)

# %%
#Because we have written our code somehow to only save the epochs with the best validation accuracy during the training,
# we created the s_test.csv with 631 images. That is why validating each epoch for 11302 images during training would be terribly time-consuming
#so we select a random s_test.csv for evaluating the network during the training process.

# %%
for i in range(10): #Shuffle the All list
  random.shuffle(All)
with open('s_test.csv'.format(i),newline='', mode='w') as csvfile: #Create s_test.csv file for evaluating the network during training
    csvwriter = csv.writer(csvfile, delimiter=',', quotechar='"', quoting=csv.QUOTE_MINIMAL)
    csvwriter.writerow(['filename','class'])
    ln=0
    lp=0
    for row in All:
      if row not in all_train:
        if row[1]=='COVID-19':
          csvwriter.writerow(row)
        elif row[1]=='normal':
          if ln<300:
            csvwriter.writerow(row)
            ln+=1
        else:
          if lp<300:
            csvwriter.writerow(row)
            lp+=1

# %% [markdown]
# # New Section

# %%
#remove the unnecessary file to increase the free space
try:
  os.remove('kaggle.zip')
  shutil.rmtree('All/stage_2_train_images')
  shutil.rmtree('All/stage_2_test_images')
  shutil.rmtree('covid-chestxray-dataset')
except:
  pass

# %%
#Here we set the data generators for applying data augmentation methods
train_datagen = ImageDataGenerator(horizontal_flip=True,vertical_flip=True,rescale=1./255,zoom_range=0.05,rotation_range=360,width_shift_range=0.05,height_shift_range=0.05,shear_range=0.05)
test_datagen = ImageDataGenerator(rescale=1./255)
test_df = pd.read_csv("s_test.csv")

# %%
# Now our data is ready
# We create the neural network in the next level
#If you want to use our trained network you can visit this shared folde:
#  https://drive.google.com/drive/folders/19R4T-D-bWUkQOh3xy5CkIDAmkLBt8ID7?usp=sharing

# %%
 mod_attrs_str = dir(keras.optimizers)
 print(mod_attrs_str)
# Out:
# ['Optimizer', 'TFOptimizer', '__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__spec__', 'adadelta_experimental', 'adadelta_v2', 'adagrad_experimental', 'adagrad_v2', 'adam_experimental', 'adam_v2', 'adamax_v2', 'backend', 'deserialize', 'deserialize_keras_object', 'ftrl', 'get', 'gradient_descent_v2', 'keras_export', 'nadam_v2', 'optimizer_experimental', 'optimizer_v2', 'rmsprop_v2', 'serialize', 'serialize_keras_object', 'sgd_experimental', 'tf']

# %%
import keras.backend as k
k.clear_session() #Clear keras backend 
try:
  os.mkdir('models')
except:
  pass
full_name='concatenate'
classes_number=3 #Number of classes
input_tensor=Input(shape=(300,300,3))
######################################################################################################
base_model1 = Xception(weights='imagenet', include_top=False, input_tensor=input_tensor)
features1 = base_model1.output
######################################################################################################
base_model2 = ResNet50V2(weights='imagenet', include_top=False, input_tensor=input_tensor)
features2 = base_model2.output
concatenated=keras.layers.concatenate([features1,features2]) #Concatenate the extracted features
####################################################################################################
conv=keras.layers.Conv2D(1024, (1, 1),padding='same')(concatenated) #add the concatenated features to a convolutional layer
feature = Flatten(name='flatten')(conv)
dp = Dropout(0.5)(feature) #add dropout
preds = Dense(classes_number, activation='softmax', kernel_initializer=RandomNormal(mean=0.0, stddev=0.001))(dp) 
Concatenated_model = Model(inputs=input_tensor, outputs=preds)
#######################################################
for layer in Concatenated_model.layers:
  layer.trainable = True
Concatenated_model.compile(optimizer=optimizers.nadam_v2.Nadam(lr=0.0001), loss='categorical_crossentropy',metrics=['accuracy'])
filepath="models/%s-{epoch:02d}-{val_accuracy:.4f}.hdf5"%full_name 
checkpoint = ModelCheckpoint(filepath, monitor='val_accuracy', save_best_only=True, mode='max') #creating checkpoint to save the best validation accuracy
callbacks_list = [checkpoint]

for epoch_num in range(1,9): # This loop applies the 8 phases for training
  train_df =pd.read_csv("train{}.csv".format(epoch_num)) #Add data generators for parsing images to the network while training
  train_generator = train_datagen.flow_from_dataframe(
        dataframe=train_df,
        directory='All/All',
        x_col="filename",
        y_col="class",
        target_size=(300, 300),
        batch_size=20,
        class_mode='categorical',shuffle=True)
  validation_generator = test_datagen.flow_from_dataframe(
          dataframe=test_df,
          directory='All/All',
          x_col="filename",
          y_col="class",
          target_size=(300, 300),
          batch_size=20,
          class_mode='categorical',shuffle=True)
  Concatenated_model.fit_generator(train_generator, epochs=100,validation_data=validation_generator,shuffle=True,callbacks=callbacks_list) #start training
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/xception/xception_weights_tf_dim_ordering_tf_kernels_notop.h5
# 83689472/83683744 [==============================] - 0s 0us/step
# 83697664/83683744 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50v2_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94674944/94668760 [==============================] - 1s 0us/step
# 94683136/94668760 [==============================] - 1s 0us/step
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/nadam.py:73: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Nadam, self).__init__(name, **kwargs)
# Found 633 validated image filenames belonging to 3 classes.
# Found 631 validated image filenames belonging to 3 classes.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:49: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
# Epoch 1/100
# 32/32 [==============================] - 96s 2s/step - loss: 0.8898 - accuracy: 0.6161 - val_loss: 0.6087 - val_accuracy: 0.7559
# Epoch 2/100
# 32/32 [==============================] - 46s 1s/step - loss: 0.6791 - accuracy: 0.7346 - val_loss: 0.6297 - val_accuracy: 0.7971
# Epoch 3/100
# 32/32 [==============================] - 43s 1s/step - loss: 0.5896 - accuracy: 0.7915 - val_loss: 0.8734 - val_accuracy: 0.6624
# Epoch 4/100
# 32/32 [==============================] - 46s 1s/step - loss: 0.5226 - accuracy: 0.8073 - val_loss: 0.3890 - val_accuracy: 0.8669
# Epoch 5/100
# 32/32 [==============================] - 43s 1s/step - loss: 0.4581 - accuracy: 0.8294 - val_loss: 0.5112 - val_accuracy: 0.8352
# Epoch 6/100
# 32/32 [==============================] - 44s 1s/step - loss: 0.2887 - accuracy: 0.8926 - val_loss: 0.4263 - val_accuracy: 0.8510
# Epoch 7/100
# 32/32 [==============================] - 44s 1s/step - loss: 0.3719 - accuracy: 0.8641 - val_loss: 0.4524 - val_accuracy: 0.8637
# Epoch 8/100
# 32/32 [==============================] - 43s 1s/step - loss: 0.3427 - accuracy: 0.8657 - val_loss: 0.6231 - val_accuracy: 0.7813
# Epoch 9/100
# 32/32 [==============================] - 43s 1s/step - loss: 0.2576 - accuracy: 0.9021 - val_loss: 0.4392 - val_accuracy: 0.8526
# Epoch 10/100
# 32/32 [==============================] - 44s 1s/step - loss: 0.2220 - accuracy: 0.9242 - val_loss: 0.6536 - val_accuracy: 0.7876
# Epoch 11/100
# 32/32 [==============================] - 44s 1s/step - loss: 0
100
# 32/32 [==============================] - 45s 1s/step - loss: 0.0363 - accuracy: 0.9858 - val_loss: 0.5238 - val_accuracy: 0.8938
# Epoch 72/100
# 32/32 [==============================] - 45s 1s/step - loss: 0.0061 - accuracy: 1.0000 - val_loss: 0.5636 - val_accuracy: 0.9065
# Epoch 73/100
# 32/32 [==============================] - 45s 1s/step - loss: 0.0076 - accuracy: 0.9953 - val_loss: 0.5688 - val_accuracy: 0.8906
# Epoch 74/100
# 32/32 [==============================] - 45s 1s/step - loss: 0.0117 - accuracy: 0.9937 - val_loss: 0.6424 - val_accuracy: 0.8621
# Epoch 75/100
# 32/32 [==============================] - 45s 1s/step - loss: 0.0436 - accuracy: 0.9889 - val_loss: 0.6034 - val_accuracy: 0.8748
# Epoch 76/100
# 32/32 [==============================] - 45s 1s/step - loss: 0.0132 - accuracy: 0.9953 - val_loss: 0.6705 - val_accuracy: 0.8811
# Epoch 77/100
# 32/32 [==============================] - 45s 1s/step - loss: 0.0255 - accuracy: 0.9874 - val_loss: 1.3278 - val_accuracy: 0.7369
# Epoch 78/100
# 32/32 [==============================] - 45s 1s/step - loss: 0.0235 - accuracy: 0.9905 - val_loss: 1.2971 - val_accuracy: 0.8209
# Epoch 79/100
# 32/32 [==============================] - 45s 1s/step - loss: 0.0689 - accuracy: 0.9795 - val_loss: 0.7311 - val_accuracy: 0.8700
# Epoch 80/100
# 32/32 [==============================] - 45s 1s/step - loss: 0.0208 - accuracy: 0.9905 - val_loss: 0.6774 - val_accuracy: 0.8811
# Epoch 81/100
# 32/32 [==============================] - 45s 1s/step - loss: 0.0072 - accuracy: 0.9968 - val_loss: 0.7585 - val_accuracy: 0.8764
# Epoch 82/100
# 32/32 [==============================] - 45s 1s/step - loss: 0.0283 - accuracy: 0.9858 - val_loss: 1.0607 - val_accuracy: 0.8431
# Epoch 83/100
# 32/32 [==============================] - 43s 1s/step - loss: 0.0503 - accuracy: 0.9858 - val_loss: 0.8616 - val_accuracy: 0.8653
# Epoch 84/100
# 32/32 [==============================] - 44s 1s/step - loss: 0.0567 - accuracy: 0.9889 - val_loss: 0.6538 - val_accuracy: 0.8764
# Epoch 85/100
# 32/32 [==============================] - 45s 1s/step - loss: 0.0474 - accuracy: 0.9889 - val_loss: 0.7617 - val_accuracy: 0.8732
# Epoch 86/100
# 32/32 [==============================] - 45s 1s/step - loss: 0.0304 - accuracy: 0.9874 - val_loss: 0.6581 - val_accuracy: 0.8637
# Epoch 87/100
# 32/32 [==============================] - 45s 1s/step - loss: 0.0524 - accuracy: 0.9795 - val_loss: 0.7386 - val_accuracy: 0.8605
# Epoch 88/100
# 32/32 [==============================] - 44s 1s/step - loss: 0.0305 - accuracy: 0.9921 - val_loss: 0.8056 - val_accuracy: 0.8399
# Epoch 89/100
# 32/32 [==============================] - 44s 1s/step - loss: 0.0390 - accuracy: 0.9858 - val_loss: 0.6798 - val_accuracy: 0.8590
# Epoch 90/100
# 32/32 [==============================] - 44s 1s/step - loss: 0.0593 - accuracy: 0.9858 - val_loss: 10.5019 - val_accuracy: 0.3534
# Epoch 91/100
# 32/32 [==============================] - 44s 1s/step - loss: 0.0186 - accuracy: 0.9937 - val_loss: 1.3471 - val_accuracy: 0.8209
# Epoch 92/100
# 32/32 [==============================] - 44s 1s/step - loss: 0.0391 - accuracy: 0.9889 - val_loss: 0.7496 - val_accuracy: 0.8590
# Epoch 93/100
# 32/32 [==============================] - 44s 1s/step - loss: 0.0683 - accuracy: 0.9826 - val_loss: 0.7731 - val_accuracy: 0.8590
# Epoch 94/100
# 32/32 [==============================] - 45s 1s/step - loss: 0.0256 - accuracy: 0.9905 - val_loss: 0.5436 - val_accuracy: 0.8891
# Epoch 95/100
# 32/32 [==============================] - 45s 1s/step - loss: 0.0836 - accuracy: 0.9842 - val_loss: 0.6542 - val_accuracy: 0.8685
# Epoch 96/100
# 32/32 [==============================] - 44s 1s/step - loss: 0.0577 - accuracy: 0.9810 - val_loss: 1.0780 - val_accuracy: 0.8875
# Epoch 97/100
# 32/32 [==============================] - 44s 1s/step - loss: 0.0420 - accuracy: 0.9858 - val_loss: 0.6777 - val_accuracy: 0.9065
# Epoch 98/100
# 32/32 [==============================] - 45s 1s/step - loss: 0.0303 - accuracy: 0.9858 - val_loss: 0.7019 - val_accuracy: 0.8954
# Epoch 99/100
# 32/32 [==============================] - 44s 1s/step - loss: 0.0222 - accuracy: 0.9874 - val_loss: 0.6170 - val_accuracy: 0.8796
# Epoch 100/100
# 32/32 [==============================] - 44s 1s/step - loss: 0.0476 - accuracy: 0.9842 - val_loss: 0.5920 - val_accuracy: 0.9097
# Found 633 validated image filenames belonging to 3 classes.
# Found 631 validated image filenames belonging to 3 classes.
# Epoch 1/100
# 32/32 [==============================] - 45s 1s/step - loss: 0
100
# 32/32 [==============================] - 44s 1s/step - loss: 0.0706 - accuracy: 0.9795 - val_loss: 0.9555 - val_accuracy: 0.8526
# Epoch 65/100
# 32/32 [==============================] - 45s 1s/step - loss: 0.1366 - accuracy: 0.9716 - val_loss: 0.7117 - val_accuracy: 0.8130
# Epoch 66/100
# 32/32 [==============================] - 45s 1s/step - loss: 0.0365 - accuracy: 0.9858 - val_loss: 0.5635 - val_accuracy: 0.8590
# Epoch 67/100
# 32/32 [==============================] - 45s 1s/step - loss: 0.0360 - accuracy: 0.9889 - val_loss: 0.5420 - val_accuracy: 0.8811
# Epoch 68/100
# 32/32 [==============================] - 45s 1s/step - loss: 0.0161 - accuracy: 0.9921 - val_loss: 0.5821 - val_accuracy: 0.8685
# Epoch 69/100
# 32/32 [==============================] - 45s 1s/step - loss: 0.0086 - accuracy: 0.9984 - val_loss: 0.6236 - val_accuracy: 0.8780
# Epoch 70/100
# 32/32 [==============================] - 45s 1s/step - loss: 0.0259 - accuracy: 0.9889 - val_loss: 0.7214 - val_accuracy: 0.8875
# Epoch 71/100
# 32/32 [==============================] - 44s 1s/step - loss: 0.0149 - accuracy: 0.9953 - val_loss: 0.9131 - val_accuracy: 0.8891
# Epoch 72/100
# 32/32 [==============================] - 45s 1s/step - loss: 0.0217 - accuracy: 0.9921 - val_loss: 0.8279 - val_accuracy: 0.8891
# Epoch 73/100
# 32/32 [==============================] - 45s 1s/step - loss: 0.0565 - accuracy: 0.9795 - val_loss: 0.7937 - val_accuracy: 0.8859
# Epoch 74/100
# 32/32 [==============================] - 45s 1s/step - loss: 0.0563 - accuracy: 0.9889 - val_loss: 0.8877 - val_accuracy: 0.9113
# Epoch 75/100
# 32/32 [==============================] - 45s 1s/step - loss: 0.0389 - accuracy: 0.9842 - val_loss: 1.2678 - val_accuracy: 0.8938
# Epoch 76/100
# 32/32 [==============================] - 45s 1s/step - loss: 0.0550 - accuracy: 0.9905 - val_loss: 0.7180 - val_accuracy: 0.8986
# Epoch 77/100
# 32/32 [==============================] - 45s 1s/step - loss: 0.0610 - accuracy: 0.9826 - val_loss: 0.8949 - val_accuracy: 0.8922
# Epoch 78/100
# 32/32 [==============================] - 45s 1s/step - loss: 0.0369 - accuracy: 0.9921 - val_loss: 0.6729 - val_accuracy: 0.8954
# Epoch 79/100
# 32/32 [==============================] - 45s 1s/step - loss: 0.0206 - accuracy: 0.9905 - val_loss: 0.9300 - val_accuracy: 0.8843
# Epoch 80/100
# 32/32 [==============================] - 45s 1s/step - loss: 0.0259 - accuracy: 0.9937 - val_loss: 0.6681 - val_accuracy: 0.8954
# Epoch 81/100
# 32/32 [==============================] - 45s 1s/step - loss: 0.0301 - accuracy: 0.9905 - val_loss: 0.9933 - val_accuracy: 0.8764
# Epoch 82/100
# 32/32 [==============================] - 45s 1s/step - loss: 0.0075 - accuracy: 0.9984 - val_loss: 0.6248 - val_accuracy: 0.8986
# Epoch 83/100
# 32/32 [==============================] - 45s 1s/step - loss: 0.0086 - accuracy: 0.9968 - val_loss: 0.5741 - val_accuracy: 0.8891
# Epoch 84/100
# 32/32 [==============================] - 45s 1s/step - loss: 0.0093 - accuracy: 0.9984 - val_loss: 0.5494 - val_accuracy: 0.8986
# Epoch 85/100
# 32/32 [==============================] - 45s 1s/step - loss: 0.0043 - accuracy: 0.9984 - val_loss: 0.5641 - val_accuracy: 0.8827
# Epoch 86/100
# 32/32 [==============================] - 44s 1s/step - loss: 0.0223 - accuracy: 0.9889 - val_loss: 0.8124 - val_accuracy: 0.8875
# Epoch 87/100
# 32/32 [==============================] - 45s 1s/step - loss: 0.0175 - accuracy: 0.9953 - val_loss: 1.0560 - val_accuracy: 0.8843
# Epoch 88/100
# 32/32 [==============================] - 45s 1s/step - loss: 0.0405 - accuracy: 0.9905 - val_loss: 0.8481 - val_accuracy: 0.8827
# Epoch 89/100
# 32/32 [==============================] - 45s 1s/step - loss: 0.0163 - accuracy: 0.9921 - val_loss: 0.6611 - val_accuracy: 0.9002
# Epoch 90/100
# 32/32 [==============================] - 44s 1s/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.6393 - val_accuracy: 0.9017
# Epoch 91/100
# 32/32 [==============================] - 45s 1s/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.6414 - val_accuracy: 0.9049
# Epoch 92/100
# 32/32 [==============================] - 45s 1s/step - loss: 0.0080 - accuracy: 0.9968 - val_loss: 0.7746 - val_accuracy: 0.8875
# Epoch 93/100
# 32/32 [==============================] - 45s 1s/step - loss: 0.0133 - accuracy: 0.9937 - val_loss: 0.9663 - val_accuracy: 0.8859
# Epoch 94/100
# 32/32 [==============================] - 45s 1s/step - loss: 0.0144 - accuracy: 0.9937 - val_loss: 0.6314 - val_accuracy: 0.8970
# Epoch 95/100
# 32/32 [==============================] - 44s 1s/step - loss: 0.0151 - accuracy: 0.9968 - val_loss: 0.6705 - val_accuracy: 0.9065
# Epoch 96/100
# 32/32 [==============================] - 44s 1s/step - loss: 0.0154 - accuracy: 0.9953 - val_loss: 0.6038 - val_accuracy: 0.9049
# Epoch 97/100
# 32/32 [==============================] - 44s 1s/step - loss: 0.0301 - accuracy: 0.9921 - val_loss: 0.7157 - val_accuracy: 0.8970
# Epoch 98/100
# 32/32 [==============================] - 45s 1s/step - loss: 0.0206 - accuracy: 0.9905 - val_loss: 1.3288 - val_accuracy: 0.8368
# Epoch 99/100
# 32/32 [==============================] - 45s 1s/step - loss: 0.0145 - accuracy: 0.9968 - val_loss: 1.0478 - val_accuracy: 0.8653
# Epoch 100/100
# 32/32 [==============================] - 45s 1s/step - loss: 0.0241 - accuracy: 0.9937 - val_loss: 0.7582 - val_accuracy: 0.8827
# Found 633 validated image filenames belonging to 3 classes.
# Found 631 validated image filenames belonging to 3 classes.
# Epoch 1/100
# 32/32 [==============================] - 44s 1s/step - loss: 0.2835 - accuracy: 0.9131 - val_loss: 0.5883 - val_accuracy: 0.8764
# Epoch 2/100
# 32/32 [==============================] - 44s 1s/step - loss: 0.1492 - accuracy: 0.9589 - val_loss: 2.4210 - val_accuracy: 0.6688
# Epoch 3/100
# 32/32 [==============================] - 44s 1s/step - loss: 0.1249 - accuracy: 0.9526 - val_loss: 0.5477 - val_accuracy: 0.8637
# Epoch 4/100
# 32/32 [==============================] - 44s 1s/step - loss: 0.0989 - accuracy: 0.9684 - val_loss: 0.7521 - val_accuracy: 0.7861
# Epoch 5/100
# 32/32 [==============================] - 43s 1s/step - loss: 0.2107 - accuracy: 0.9352 - val_loss: 0.4091 - val_accuracy: 0.9017
# Epoch 6/100
# 32/32 [==============================] - 44s 1s/step - loss: 0.1131 - accuracy: 0.9621 - val_loss: 0.3966 - val_accuracy: 0.9128
# Epoch 7/100
# 32/32 [==============================] - 44s 1s/step - loss: 0.0721 - accuracy: 0.9779 - val_loss: 0.3700 - val_accuracy: 0.9128
# Epoch 8/100
# 32/32 [==============================] - 44s 1s/step - loss: 0.0485 - accuracy: 0.9795 - val_loss: 0.4235 - val_accuracy: 0.9128
# Epoch 9/100
# 32/32 [==============================] - 43s 1s/step - loss: 0.0595 - accuracy: 0.9763 - val_loss: 0.3981 - val_accuracy: 0.8970
# Epoch 10/100
# 32/32 [==============================] - 44s 1s/step - loss: 0.0419 - accuracy: 0.9795 - val_loss: 0.4505 - val_accuracy: 0.8922
# Epoch 11/100
# 32/32 [==============================] - 44s 1s/step - loss: 0.0173 - accuracy: 0.9905 - val_loss: 0.5203 - val_accuracy: 0.8986
# Epoch 12/100
# 32/32 [==============================] - 45s 1s/step - loss: 0.0422 - accuracy: 0.9842 - val_loss: 0.6643 - val_accuracy: 0.8811
# Epoch 13/100
# 32/32 [==============================] - 44s 1s/step - loss: 0.0448 - accuracy: 0.9858 - val_loss: 0.4562 - val_accuracy: 0.9081
# Epoch 14/100
# 32/32 [==============================] - 44s 1s/step - loss: 0.0313 - accuracy: 0.9889 - val_loss: 0.5242 - val_accuracy: 0.9002
# Epoch 15/100
# 32/32 [==============================] - 44s 1s/step - loss: 0.0376 - accuracy: 0.9874 - val_loss: 0.6715 - val_accuracy: 0.8796
# Epoch 16/100
# 32/32 [==============================] - 45s 1s/step - loss: 0.0341 - accuracy: 0.9921 - val_loss: 0.5579 - val_accuracy: 0.8875
# Epoch 17/100
# 32/32 [==============================] - 45s 1s/step - loss: 0.0263 - accuracy: 0.9905 - val_loss: 0.6588 - val_accuracy: 0.8368
# Epoch 18/100
# 32/32 [==============================] - 44s 1s/step - loss: 0.0551 - accuracy: 0.9874 - val_loss: 1.1379 - val_accuracy: 0.8669
# Epoch 19/100
# 32/32 [==============================] - 45s 1s/step - loss: 0.1085 - accuracy: 0.9826 - val_loss: 0.5154 - val_accuracy: 0.9160
# Epoch 20/100
# 32/32 [==============================] - 45s 1s/step - loss: 0.0461 - accuracy: 0.9905 - val_loss: 0.9204 - val_accuracy: 0.8827
# Epoch 21/100
# 32/32 [==============================] - 45s 1s/step - loss: 0.0847 - accuracy: 0.9810 - val_loss: 0.6615 - val_accuracy: 0.8843
# Epoch 22/100
# 32/32 [==============================] - 44s 1s/step - loss: 0.0354 - accuracy: 0.9826 - val_loss: 0.9422 - val_accuracy: 0.8637
# Epoch 23/100
# 32/32 [==============================] - 44s 1s/step - loss: 0.0292 - accuracy: 0.9905 - val_loss: 0.6791 - val_accuracy: 0.8875
# Epoch 24/100
# 32/32 [==============================] - 45s 1s/step - loss: 0.0183 - accuracy: 0.9937 - val_loss: 1.1490 - val_accuracy: 0.8605
# Epoch 25/100
# 32/32 [==============================] - 44s 1s/step - loss: 0.0228 - accuracy: 0.9921 - val_loss: 0.6260 - val_accuracy: 0.8590
# Epoch 26/100
# 32/32 [==============================] - 45s 1s/step - loss: 0.0150 - accuracy: 0.9953 - val_loss: 0.6030 - val_accuracy: 0.8843
# Epoch 27/100
# 32/32 [==============================] - 45s 1s/step - loss: 0.0036 - accuracy: 1.0000 - val_loss: 0.6532 - val_accuracy: 0.8891
# Epoch 28/100
# 32/32 [==============================] - 44s 1s/step - loss: 0.0150 - accuracy: 0.9953 - val_loss: 0.6373 - val_accuracy: 0.8986
# Epoch 29/100
# 32/32 [==============================] - 45s 1s/step - loss: 0.0245 - accuracy: 0.9937 - val_loss: 0.7830 - val_accuracy: 0.9049
# Epoch 30/100
# 32/32 [==============================] - 43s 1s/step - loss: 0.0227 - accuracy: 0.9953 - val_loss: 0.7020 - val_accuracy: 0.9081
# Epoch 31/100
# 32/32 [==============================] - 44s 1s/step - loss: 0.0491 - accuracy: 0.9858 - val_loss: 0.8394 - val_accuracy: 0.9033
# Epoch 32/100
# 32/32 [==============================] - 44s 1s/step - loss: 0.1206 - accuracy: 0.9716 - val_loss: 15.3421 - val_accuracy: 0.5119
# Epoch 33/100
# 32/32 [==============================] - 43s 1s/step - loss: 0.2119 - accuracy: 0.9700 - val_loss: 1190.5474 - val_accuracy: 0.1632
# Epoch 34/100
# 32/32 [==============================] - 43s 1s/step - loss: 0.0790 - accuracy: 0.9779 - val_loss: 253.2264 - val_accuracy: 0.1458
# Epoch 35/100
# 32/32 [==============================] - 44s 1s/step - loss: 0.2488 - accuracy: 0.9716 - val_loss: 2.4166 - val_accuracy: 0.7781
# Epoch 36/100
# 32/32 [==============================] - 44s 1s/step - loss: 0.2983 - accuracy: 0.9526 - val_loss: 33.4715 - val_accuracy: 0.5420
# Epoch 37/100
# 32/32 [==============================] - 44s 1s/step - loss: 0.1463 - accuracy: 0.9763 - val_loss: 23.6197 - val_accuracy: 0.5610
# Epoch 38/100
# 32/32 [==============================] - 44s 1s/step - loss: 0.1438 - accuracy: 0.9763 - val_loss: 0.8100 - val_accuracy: 0.8922
# Epoch 39/100
# 32/32 [==============================] - 44s 1s/step - loss: 0.1419 - accuracy: 0.9700 - val_loss: 1.0447 - val_accuracy: 0.9113
# Epoch 40/100
# 32/32 [==============================] - 43s 1s/step - loss: 0.0911 - accuracy: 0.9779 - val_loss: 1.0502 - val_accuracy: 0.8922
# Epoch 41/100
# 32/32 [==============================] - 44s 1s/step - loss: 0.0446 - accuracy: 0.9810 - val_loss: 1.0337 - val_accuracy: 0.9033
# Epoch 42/100
# 32/32 [==============================] - 44s 1s/step - loss: 0.0745 - accuracy: 0.9874 - val_loss: 1.0075 - val_accuracy: 0.9033
# Epoch 43/100
# 32/32 [==============================] - 44s 1s/step - loss: 0.0223 - accuracy: 0.9937 - val_loss: 1.0497 - val_accuracy: 0.8875
# Epoch 44/100
# 32/32 [==============================] - 45s 1s/step - loss: 0.0215 - accuracy: 0.9905 - val_loss: 1.1727 - val_accuracy: 0.8875
# Epoch 45/100
# 32/32 [==============================] - 44s 1s/step - loss: 0.0535 - accuracy: 0.9826 - val_loss: 1.1429 - val_accuracy: 0.9017
# Epoch 46/100
# 32/32 [==============================] - 44s 1s/step - loss: 0.0418 - accuracy: 0.9874 - val_loss: 1.3688 - val_accuracy: 0.8875
# Epoch 47/100
# 32/32 [==============================] - 43s 1s/step - loss: 0.0514 - accuracy: 0.9874 - val_loss: 1.1981 - val_accuracy: 0.8938
# Epoch 48/100
# 32/32 [==============================] - 43s 1s/step - loss: 0.0239 - accuracy: 0.9921 - val_loss: 1.2725 - val_accuracy: 0.8875
# Epoch 49/100
# 32/32 [==============================] - 44s 1s/step - loss: 0.0114 - accuracy: 0.9953 - val_loss: 1.4342 - val_accuracy: 0.8906
# Epoch 50/100
# 32/32 [==============================] - 44s 1s/step - loss: 0.0580 - accuracy: 0.9905 - val_loss: 1.2010 - val_accuracy: 0.8685
# Epoch 51/100
# 32/32 [==============================] - 43s 1s/step - loss: 0.0189 - accuracy: 0.9937 - val_loss: 1.3639 - val_accuracy: 0.8288
# Epoch 52/100
# 32/32 [==============================] - 44s 1s/step - loss: 0.0174 - accuracy: 0.9921 - val_loss: 1.6357 - val_accuracy: 0.8827
# Epoch 53/100
# 32/32 [==============================] - 44s 1s/step - loss: 0.0295 - accuracy: 0.9937 - val_loss: 1.6379 - val_accuracy: 0.8875
# Epoch 54/100
# 32/32 [==============================] - 44s 1s/step - loss: 0.0685 - accuracy: 0.9842 - val_loss: 1.4694 - val_accuracy: 0.8970
# Epoch 55/100
# 32/32 [==============================] - 44s 1s/step - loss: 0.1180 - accuracy: 0.9889 - val_loss: 1.4095 - val_accuracy: 0.9049
# Epoch 56/100
# 32/32 [==============================] - 43s 1s/step - loss: 0.0508 - accuracy: 0.9905 - val_loss: 1.3616 - val_accuracy: 0.8922
# Epoch 57/100
# 32/32 [==============================] - 44s 1s/step - loss: 0.0153 - accuracy: 0.9968 - val_loss: 1.0657 - val_accuracy: 0.9017
# Epoch 58/100
# 32/32 [==============================] - 44s 1s/step - loss: 0.0385 - accuracy: 0.9905 - val_loss: 1.0916 - val_accuracy: 0.9033
# Epoch 59/100
# 32/32 [==============================] - 44s 1s/step - loss: 0.0412 - accuracy: 0.9905 - val_loss: 1.1641 - val_accuracy: 0.9065
# Epoch 60/100
# 32/32 [==============================] - 46s 1s/step - loss: 0.0185 - accuracy: 0.9937 - val_loss: 1.3130 - val_accuracy: 0.8986
# Epoch 61/100
# 32/32 [==============================] - 45s 1s/step - loss: 0.0236 - accuracy: 0.9921 - val_loss: 1.4907 - val_accuracy: 0.8827
# Epoch 62/100
# 32/32 [==============================] - 45s 1s/step - loss: 0.0320 - accuracy: 0.9968 - val_loss: 1.3516 - val_accuracy: 0.8986
# Epoch 63/100
# 32/32 [==============================] - 45s 1s/step - loss: 0.0367 - accuracy: 0.9905 - val_loss: 1.1570 - val_accuracy: 0.9033
# Epoch 64/100
# 32/32 [==============================] - 45s 1s/step - loss: 0.0129 - accuracy: 0.9937 - val_loss: 1.4331 - val_accuracy: 0.8827
# Epoch 65/100
# 32/32 [==============================] - 45s 1s/step - loss: 0.0248 - accuracy: 0.9968 - val_loss: 1.0342 - val_accuracy: 0.8922
# Epoch 66/100
# 32/32 [==============================] - 45s 1s/step - loss: 0.0249 - accuracy: 0.9937 - val_loss: 1.5689 - val_accuracy: 0.8732
# Epoch 67/100
# 32/32 [==============================] - 45s 1s/step - loss: 0.0444 - accuracy: 0.9921 - val_loss: 1.4165 - val_accuracy: 0.8764
# Epoch 68/100
# 32/32 [==============================] - 44s 1s/step - loss: 0.0151 - accuracy: 0.9953 - val_loss: 1.6540 - val_accuracy: 0.8653
# Epoch 69/100
# 32/32 [==============================] - 44s 1s/step - loss: 0.0182 - accuracy: 0.9905 - val_loss: 1.2032 - val_accuracy: 0.8938
# Epoch 70/100
# 32/32 [==============================] - 44s 1s/step - loss: 0.0098 - accuracy: 0.9968 - val_loss: 1.7905 - val_accuracy: 0.8700
# Epoch 71/100
# 32/32 [==============================] - 44s 1s/step - loss: 0.0252 - accuracy: 0.9937 - val_loss: 1.0110 - val_accuracy: 0.8906
# Epoch 72/100
# 32/32 [==============================] - 45s 1s/step - loss: 0.0030 - accuracy: 1.0000 - val_loss: 1.0529 - val_accuracy: 0.8922
# Epoch 73/100
# 32/32 [==============================] - 44s 1s/step - loss: 9.1873e-04 - accuracy: 1.0000 - val_loss: 1.1176 - val_accuracy: 0.8906
# Epoch 74/100
# 32/32 [==============================] - 45s 1s/step - loss: 0.0159 - accuracy: 0.9968 - val_loss: 2.2205 - val_accuracy: 0.8558
# Epoch 75/100
# 32/32 [==============================] - 45s 1s/step - loss: 0.0289 - accuracy: 0.9905 - val_loss: 1.6722 - val_accuracy: 0.8859
# Epoch 76/100
# 32/32 [==============================] - 44s 1s/step - loss: 0.0387 - accuracy: 0.9937 - val_loss: 1.1392 - val_accuracy: 0.8938
# Epoch 77/100
# 32/32 [==============================] - 45s 1s/step - loss: 0.0205 - accuracy: 0.9953 - val_loss: 1.0919 - val_accuracy: 0.8938
# Epoch 78/100
# 32/32 [==============================] - 45s 1s/step - loss: 0.0208 - accuracy: 0.9921 - val_loss: 1.0487 - val_accuracy: 0.8827
# Epoch 79/100
# 32/32 [==============================] - 44s 1s/step - loss: 0.0211 - accuracy: 0.9953 - val_loss: 1.7079 - val_accuracy: 0.8843
# Epoch 80/100
# 32/32 [==============================] - 43s 1s/step - loss: 0.0218 - accuracy: 0.9953 - val_loss: 1.6221 - val_accuracy: 0.8130
# Epoch 81/100
# 32/32 [==============================] - 43s 1s/step - loss: 0.0189 - accuracy: 0.9953 - val_loss: 1.0313 - val_accuracy: 0.8954
# Epoch 82/100
# 32/32 [==============================] - 44s 1s/step - loss: 0.0037 - accuracy: 0.9984 - val_loss: 1.0297 - val_accuracy: 0.8859
# Epoch 83/100
# 32/32 [==============================] - 44s 1s/step - loss: 0.0036 - accuracy: 0.9984 - val_loss: 1.0744 - val_accuracy: 0.8891
# Epoch 84/100
# 32/32 [==============================] - 44s 1s/step - loss: 0.0239 - accuracy: 0.9968 - val_loss: 1.2693 - val_accuracy: 0.8669
# Epoch 85/100
# 32/32 [==============================] - 45s 1s/step - loss: 0.0189 - accuracy: 0.9937 - val_loss: 1.3999 - val_accuracy: 0.8780
# Epoch 86/100
# 32/32 [==============================] - 44s 1s/step - loss: 0.0110 - accuracy: 0.9968 - val_loss: 1.1154 - val_accuracy: 0.8875
# Epoch 87/100
# 32/32 [==============================] - 44s 1s/step - loss: 0.0071 - accuracy: 0.9968 - val_loss: 1.3205 - val_accuracy: 0.8859
# Epoch 88/100
# 32/32 [==============================] - 44s 1s/step - loss: 0.0127 - accuracy: 0.9984 - val_loss: 1.2173 - val_accuracy: 0.8938
# Epoch 89/100
# 32/32 [==============================] - 44s 1s/step - loss: 0.0069 - accuracy: 0.9968 - val_loss: 1.0041 - val_accuracy: 0.9033
# Epoch 90/100
# 32/32 [==============================] - 45s 1s/step - loss: 0.0021 - accuracy: 0.9984 - val_loss: 1.0326 - val_accuracy: 0.8986
# Epoch 91/100
# 32/32 [==============================] - 45s 1s/step - loss: 1.0530e-04 - accuracy: 1.0000 - val_loss: 1.0527 - val_accuracy: 0.8986
# Epoch 92/100
# 32/32 [==============================] - 44s 1s/step - loss: 0.0049 - accuracy: 0.9984 - val_loss: 1.5183 - val_accuracy: 0.8875
# Epoch 93/100
# 32/32 [==============================] - 43s 1s/step - loss: 0.0024 - accuracy: 0.9984 - val_loss: 1.2550 - val_accuracy: 0.8970
# Epoch 94/100
# 32/32 [==============================] - 44s 1s/step - loss: 0.0190 - accuracy: 0.9953 - val_loss: 1.3243 - val_accuracy: 0.8891
# Epoch 95/100
# 32/32 [==============================] - 44s 1s/step - loss: 0.0140 - accuracy: 0.9953 - val_loss: 1.0035 - val_accuracy: 0.8986
# Epoch 96/100
# 32/32 [==============================] - 44s 1s/step - loss: 0.0093 - accuracy: 0.9968 - val_loss: 0.8310 - val_accuracy: 0.9049
# Epoch 97/100
# 32/32 [==============================] - 45s 1s/step - loss: 0.0035 - accuracy: 0.9968 - val_loss: 1.1117 - val_accuracy: 0.8954
# Epoch 98/100
# 32/32 [==============================] - 44s 1s/step - loss: 0.0245 - accuracy: 0.9937 - val_loss: 1.1455 - val_accuracy: 0.8732
# Epoch 99/100
# 32/32 [==============================] - 44s 1s/step - loss: 0.0438 - accuracy: 0.9937 - val_loss: 4.1983 - val_accuracy: 0.7464
# Epoch 100/100
# 32/32 [==============================] - 44s 1s/step - loss: 0.0095 - accuracy: 0.9968 - val_loss: 2.0065 - val_accuracy: 0.8368
# Found 633 validated image filenames belonging to 3 classes.
# Found 631 validated image filenames belonging to 3 classes.
# Epoch 1/100
# 32/32 [==============================] - 44s 1s/step - loss: 0.4174 - accuracy: 0.8926 - val_loss: 0.5778 - val_accuracy: 0.8986
# Epoch 2/100
# 32/32 [==============================] - 44s 1s/step - loss: 0.1956 - accuracy: 0.9352 - val_loss: 0.4978 - val_accuracy: 0.8970
# Epoch 3/100
# 32/32 [==============================] - 44s 1s/step - loss: 0.1553 - accuracy: 0.9400 - val_loss: 0.5759 - val_accuracy: 0.8970
# Epoch 4/100
# 32/32 [==============================] - 45s 1s/step - loss: 0.1032 - accuracy: 0.9589 - val_loss: 0.4023 - val_accuracy: 0.9113
# Epoch 5/100
# 32/32 [==============================] - 45s 1s/step - loss: 0.0866 - accuracy: 0.9605 - val_loss: 0.4336 - val_accuracy: 0.9081
# Epoch 6/100
# 32/32 [==============================] - 45s 1s/step - loss: 0.0642 - accuracy: 0.9747 - val_loss: 0.5614 - val_accuracy: 0.8922
# Epoch 7/100
# 32/32 [==============================] - 46s 1s/step - loss: 0.0841 - accuracy: 0.9763 - val_loss: 0.4951 - val_accuracy: 0.8859
# Epoch 8/100
# 32/32 [==============================] - 45s 1s/step - loss: 0.0649 - accuracy: 0.9810 - val_loss: 0.4904 - val_accuracy: 0.8891
# Epoch 9/100
# 32/32 [==============================] - 46s 1s/step - loss: 0.0285 - accuracy: 0.9889 - val_loss: 0.5631 - val_accuracy: 0.8970
# Epoch 10/100
# 32/32 [==============================] - 46s 1s/step - loss: 0.0728 - accuracy: 0.9763 - val_loss: 0.5197 - val_accuracy: 0.8986
# Epoch 11/100
# 32/32 [==============================] - 46s 1s/step - loss: 0.0722 - accuracy: 0.9763 - val_loss: 0.6156 - val_accuracy: 0.8986
# Epoch 12/100
# 32/32 [==============================] - 46s 1s/step - loss: 0.0290 - accuracy: 0.9921 - val_loss: 0.6451 - val_accuracy: 0.8875
# Epoch 13/100
# 32/32 [==============================] - 45s 1s/step - loss: 0.0280 - accuracy: 0.9889 - val_loss: 0.6435 - val_accuracy: 0.8954
# Epoch 14/100
# 32/32 [==============================] - 46s 1s/step - loss: 0.0342 - accuracy: 0.9905 - val_loss: 0.5536 - val_accuracy: 0.9097
# Epoch 15/100
# 32/32 [==============================] - 46s 1s/step - loss: 0.0287 - accuracy: 0.9905 - val_loss: 0.5833 - val_accuracy: 0.9002
# Epoch 16/100
# 32/32 [==============================] - 46s 1s/step - loss: 0.0448 - accuracy: 0.9826 - val_loss: 0.6935 - val_accuracy: 0.8922
# Epoch 17/100
# 32/32 [==============================] - 46s 1s/step - loss: 0.0137 - accuracy: 0.9968 - val_loss: 0.8541 - val_accuracy: 0.8796
# Epoch 18/100
# 32/32 [==============================] - 45s 1s/step - loss: 0.0456 - accuracy: 0.9889 - val_loss: 0.6584 - val_accuracy: 0.8875
# Epoch 19/100
# 32/32 [==============================] - 47s 1s/step - loss: 0.0229 - accuracy: 0.9905 - val_loss: 0.5532 - val_accuracy: 0.9017
# Epoch 20/100
# 32/32 [==============================] - 45s 1s/step - loss: 0.0391 - accuracy: 0.9874 - val_loss: 0.7121 - val_accuracy: 0.8906
# Epoch 21/100
# 32/32 [==============================] - 47s 1s/step - loss: 0.0085 - accuracy: 0.9984 - val_loss: 0.8018 - val_accuracy: 0.8875
# Epoch 22/100
# 32/32 [==============================] - 45s 1s/step - loss: 0.0063 - accuracy: 0.9984 - val_loss: 0.7605 - val_accuracy: 0.8906
# Epoch 23/100
# 32/32 [==============================] - 46s 1s/step - loss: 0.0156 - accuracy: 0.9921 - val_loss: 0.9047 - val_accuracy: 0.8811
# Epoch 24/100
# 32/32 [==============================] - 46s 1s/step - loss: 0.0252 - accuracy: 0.9937 - val_loss: 0.9310 - val_accuracy: 0.8827
# Epoch 25/100
# 32/32 [==============================] - 45s 1s/step - loss: 0.0201 - accuracy: 0.9937 - val_loss: 0.8425 - val_accuracy: 0.8906
# Epoch 26/100
# 32/32 [==============================] - 46s 1s/step - loss: 0.0143 - accuracy: 0.9937 - val_loss: 0.7966 - val_accuracy: 0.8938
# Epoch 27/100
# 32/32 [==============================] - 45s 1s/step - loss: 0.0185 - accuracy: 0.9953 - val_loss: 0.7302 - val_accuracy: 0.8891
# Epoch 28/100
# 32/32 [==============================] - 45s 1s/step - loss: 0.0130 - accuracy: 0.9921 - val_loss: 0.9079 - val_accuracy: 0.8748
# Epoch 29/100
# 32/32 [==============================] - 46s 1s/step - loss: 0.0086 - accuracy: 0.9968 - val_loss: 0.8102 - val_accuracy: 0.8875
# Epoch 30/100
# 32/32 [==============================] - 45s 1s/step - loss: 0.0490 - accuracy: 0.9874 - val_loss: 1.2461 - val_accuracy: 0.8447
# Epoch 31/100
# 32/32 [==============================] - 45s 1s/step - loss: 0.0413 - accuracy: 0.9889 - val_loss: 0.6004 - val_accuracy: 0.8938
# Epoch 32/100
# 32/32 [==============================] - 46s 1s/step - loss: 0.0110 - accuracy: 0.9937 - val_loss: 0.7545 - val_accuracy: 0.8780
# Epoch 33/100
# 32/32 [==============================] - 45s 1s/step - loss: 0.0633 - accuracy: 0.9795 - val_loss: 0.7558 - val_accuracy: 0.8954
# Epoch 34/100
# 32/32 [==============================] - 45s 1s/step - loss: 0.0717 - accuracy: 0.9795 - val_loss: 0.5610 - val_accuracy: 0.8986
# Epoch 35/100
# 32/32 [==============================] - 45s 1s/step - loss: 0.1046 - accuracy: 0.9779 - val_loss: 1.0792 - val_accuracy: 0.8906
# Epoch 36/100
# 32/32 [==============================] - 45s 1s/step - loss: 0.0673 - accuracy: 0.9842 - val_loss: 0.8113 - val_accuracy: 0.8843
# Epoch 37/100
# 32/32 [==============================] - 45s 1s/step - loss: 0.0245 - accuracy: 0.9937 - val_loss: 0.8792 - val_accuracy: 0.8922
# Epoch 38/100
# 32/32 [==============================] - 46s 1s/step - loss: 0.0094 - accuracy: 0.9953 - val_loss: 0.8557 - val_accuracy: 0.9033
# Epoch 39/100
# 32/32 [==============================] - 45s 1s/step - loss: 0.0469 - accuracy: 0.9889 - val_loss: 0.8148 - val_accuracy: 0.8986
# Epoch 40/100
# 32/32 [==============================] - 46s 1s/step - loss: 0.0340 - accuracy: 0.9937 - val_loss: 0.9327 - val_accuracy: 0.8875
# Epoch 41/100
# 32/32 [==============================] - 45s 1s/step - loss: 0.0131 - accuracy: 0.9968 - val_loss: 0.9640 - val_accuracy: 0.8653
# Epoch 42/100
# 32/32 [==============================] - 45s 1s/step - loss: 0.0221 - accuracy: 0.9874 - val_loss: 0.8104 - val_accuracy: 0.8986
# Epoch 43/100
# 32/32 [==============================] - 45s 1s/step - loss: 0.0414 - accuracy: 0.9858 - val_loss: 1.1415 - val_accuracy: 0.8764
# Epoch 44/100
# 32/32 [==============================] - 46s 1s/step - loss: 0.0299 - accuracy: 0.9921 - val_loss: 1.0110 - val_accuracy: 0.8716
# Epoch 45/100
# 32/32 [==============================] - 46s 1s/step - loss: 0.0197 - accuracy: 0.9937 - val_loss: 1.9337 - val_accuracy: 0.8003
# Epoch 46/100
# 32/32 [==============================] - 45s 1s/step - loss: 0.0084 - accuracy: 0.9968 - val_loss: 0.7638 - val_accuracy: 0.8859
# Epoch 47/100
# 32/32 [==============================] - 46s 1s/step - loss: 0.0188 - accuracy: 0.9921 - val_loss: 0.7339 - val_accuracy: 0.8922
# Epoch 48/100
# 32/32 [==============================] - 45s 1s/step - loss: 0.0362 - accuracy: 0.9889 - val_loss: 1.0317 - val_accuracy: 0.8827
# Epoch 49/100
# 32/32 [==============================] - 45s 1s/step - loss: 0.0363 - accuracy: 0.9921 - val_loss: 1.0067 - val_accuracy: 0.8970
# Epoch 50/100
# 32/32 [==============================] - 45s 1s/step - loss: 0.0324 - accuracy: 0.9889 - val_loss: 1.0193 - val_accuracy: 0.8875
# Epoch 51/100
# 32/32 [==============================] - 45s 1s/step - loss: 0.0127 - accuracy: 0.9953 - val_loss: 1.2164 - val_accuracy: 0.8748
# Epoch 52/100
# 32/32 [==============================] - 45s 1s/step - loss: 0.0153 - accuracy: 0.9937 - val_loss: 0.7965 - val_accuracy: 0.8922
# Epoch 53/100
# 32/32 [==============================] - 46s 1s/step - loss: 0.0074 - accuracy: 0.9968 - val_loss: 0.9255 - val_accuracy: 0.8875
# Epoch 54/100
# 32/32 [==============================] - 45s 1s/step - loss: 0.0274 - accuracy: 0.9953 - val_loss: 1.0546 - val_accuracy: 0.8685
# Epoch 55/100
# 32/32 [==============================] - 45s 1s/step - loss: 0.0160 - accuracy: 0.9968 - val_loss: 1.1616 - val_accuracy: 0.8590
# Epoch 56/100
# 32/32 [==============================] - 46s 1s/step - loss: 0.0060 - accuracy: 0.9968 - val_loss: 0.7616 - val_accuracy: 0.8827
# Epoch 57/100
# 32/32 [==============================] - 46s 1s/step - loss: 0.0149 - accuracy: 0.9937 - val_loss: 0.6848 - val_accuracy: 0.8986
# Epoch 58/100
# 32/32 [==============================] - 46s 1s/step - loss: 0.0134 - accuracy: 0.9953 - val_loss: 0.9016 - val_accuracy: 0.8843
# Epoch 59/100
# 32/32 [==============================] - 46s 1s/step - loss: 0.0130 - accuracy: 0.9953 - val_loss: 1.0921 - val_accuracy: 0.8653
# Epoch 60/100
# 32/32 [==============================] - 46s 1s/step - loss: 0.0047 - accuracy: 0.9984 - val_loss: 0.8414 - val_accuracy: 0.8811
# Epoch 61/100
# 32/32 [==============================] - 45s 1s/step - loss: 0.0045 - accuracy: 0.9984 - val_loss: 0.8582 - val_accuracy: 0.8827
# Epoch 62/100
# 32/32 [==============================] - 45s 1s/step - loss: 0.0025 - accuracy: 0.9984 - val_loss: 0.9117 - val_accuracy: 0.8875
# Epoch 63/100
# 32/32 [==============================] - 46s 1s/step - loss: 0.0315 - accuracy: 0.9937 - val_loss: 0.7512 - val_accuracy: 0.8938
# Epoch 64/100
# 32/32 [==============================] - 46s 1s/step - loss: 0.0582 - accuracy: 0.9905 - val_loss: 0.7048 - val_accuracy: 0.8922
# Epoch 65/100
# 32/32 [==============================] - 45s 1s/step - loss: 0.0620 - accuracy: 0.9858 - val_loss: 1.0740 - val_accuracy: 0.8542
# Epoch 66/100
# 32/32 [==============================] - 46s 1s/step - loss: 0.0129 - accuracy: 0.9953 - val_loss: 1.1116 - val_accuracy: 0.8479
# Epoch 67/100
# 32/32 [==============================] - 46s 1s/step - loss: 0.0059 - accuracy: 0.9968 - val_loss: 0.9637 - val_accuracy: 0.8716
# Epoch 68/100
# 32/32 [==============================] - 45s 1s/step - loss: 0.0158 - accuracy: 0.9953 - val_loss: 0.8389 - val_accuracy: 0.8621
# Epoch 69/100
# 32/32 [==============================] - 46s 1s/step - loss: 0.0056 - accuracy: 0.9968 - val_loss: 1.1244 - val_accuracy: 0.8574
# Epoch 70/100
# 32/32 [==============================] - 45s 1s/step - loss: 0.0144 - accuracy: 0.9953 - val_loss: 0.7717 - val_accuracy: 0.8938
# Epoch 71/100
# 32/32 [==============================] - 46s 1s/step - loss: 0.0154 - accuracy: 0.9953 - val_loss: 1.3927 - val_accuracy: 0.8796
# Epoch 72/100
# 32/32 [==============================] - 45s 1s/step - loss: 0.0533 - accuracy: 0.9905 - val_loss: 0.8401 - val_accuracy: 0.8796
# Epoch 73/100
# 32/32 [==============================] - 46s 1s/step - loss: 0.0316 - accuracy: 0.9905 - val_loss: 0.9456 - val_accuracy: 0.8780
# Epoch 74/100
# 32/32 [==============================] - 45s 1s/step - loss: 0.0103 - accuracy: 0.9968 - val_loss: 1.0734 - val_accuracy: 0.8716
# Epoch 75/100
# 32/32 [==============================] - 45s 1s/step - loss: 0.0204 - accuracy: 0.9937 - val_loss: 1.4017 - val_accuracy: 0.8479
# Epoch 76/100
# 32/32 [==============================] - 45s 1s/step - loss: 0.0381 - accuracy: 0.9905 - val_loss: 0.9199 - val_accuracy: 0.8732
# Epoch 77/100
# 32/32 [==============================] - 45s 1s/step - loss: 0.0233 - accuracy: 0.9905 - val_loss: 0.8636 - val_accuracy: 0.8875
# Epoch 78/100
# 32/32 [==============================] - 45s 1s/step - loss: 0.0276 - accuracy: 0.9905 - val_loss: 0.8057 - val_accuracy: 0.8970
# Epoch 79/100
# 32/32 [==============================] - 46s 1s/step - loss: 0.0353 - accuracy: 0.9937 - val_loss: 0.8882 - val_accuracy: 0.8954
# Epoch 80/100
# 32/32 [==============================] - 45s 1s/step - loss: 0.0096 - accuracy: 0.9953 - val_loss: 1.1446 - val_accuracy: 0.8906
# Epoch 81/100
# 32/32 [==============================] - 46s 1s/step - loss: 0.0179 - accuracy: 0.9968 - val_loss: 1.0921 - val_accuracy: 0.8859
# Epoch 82/100
# 32/32 [==============================] - 45s 1s/step - loss: 0.0093 - accuracy: 0.9968 - val_loss: 1.7342 - val_accuracy: 0.8209
# Epoch 83/100
# 32/32 [==============================] - 46s 1s/step - loss: 0.0932 - accuracy: 0.9858 - val_loss: 1.0732 - val_accuracy: 0.8796
# Epoch 84/100
# 32/32 [==============================] - 46s 1s/step - loss: 0.0063 - accuracy: 0.9968 - val_loss: 1.5193 - val_accuracy: 0.8542
# Epoch 85/100
# 32/32 [==============================] - 45s 1s/step - loss: 0.0074 - accuracy: 0.9984 - val_loss: 1.0973 - val_accuracy: 0.8827
# Epoch 86/100
# 32/32 [==============================] - 46s 1s/step - loss: 0.0026 - accuracy: 0.9984 - val_loss: 1.1930 - val_accuracy: 0.8827
# Epoch 87/100
# 32/32 [==============================] - 45s 1s/step - loss: 9.7727e-04 - accuracy: 1.0000 - val_loss: 0.9323 - val_accuracy: 0.8986
# Epoch 88/100
# 32/32 [==============================] - 45s 1s/step - loss: 0.0028 - accuracy: 0.9984 - val_loss: 0.8961 - val_accuracy: 0.9049
# Epoch 89/100
# 32/32 [==============================] - 45s 1s/step - loss: 0.0438 - accuracy: 0.9905 - val_loss: 1.0304 - val_accuracy: 0.8811
# Epoch 90/100
# 32/32 [==============================] - 45s 1s/step - loss: 0.0511 - accuracy: 0.9889 - val_loss: 1.2858 - val_accuracy: 0.8764
# Epoch 91/100
# 32/32 [==============================] - 46s 1s/step - loss: 0.0152 - accuracy: 0.9953 - val_loss: 1.0832 - val_accuracy: 0.8986
# Epoch 92/100
# 32/32 [==============================] - 46s 1s/step - loss: 0.0339 - accuracy: 0.9953 - val_loss: 1.0131 - val_accuracy: 0.9002
# Epoch 93/100
# 32/32 [==============================] - 46s 1s/step - loss: 0.0157 - accuracy: 0.9968 - val_loss: 1.0184 - val_accuracy: 0.8970
# Epoch 94/100
# 32/32 [==============================] - 46s 1s/step - loss: 0.0114 - accuracy: 0.9984 - val_loss: 1.1229 - val_accuracy: 0.8891
# Epoch 95/100
# 32/32 [==============================] - 46s 1s/step - loss: 0.0036 - accuracy: 0.9984 - val_loss: 1.0025 - val_accuracy: 0.8938
# Epoch 96/100
# 32/32 [==============================] - 45s 1s/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 1.0006 - val_accuracy: 0.8906
# Epoch 97/100
# 32/32 [==============================] - 46s 1s/step - loss: 0.0076 - accuracy: 0.9953 - val_loss: 0.8433 - val_accuracy: 0.8954
# Epoch 98/100
# 32/32 [==============================] - 46s 1s/step - loss: 6.8367e-04 - accuracy: 1.0000 - val_loss: 0.8915 - val_accuracy: 0.8986
# Epoch 99/100
# 32/32 [==============================] - 45s 1s/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.9780 - val_accuracy: 0.8938
# Epoch 100/100
# 32/32 [==============================] - 45s 1s/step - loss: 0.0061 - accuracy: 0.9968 - val_loss: 0.9428 - val_accuracy: 0.9065
# Found 633 validated image filenames belonging to 3 classes.
# Found 631 validated image filenames belonging to 3 classes.
# Epoch 1/100
# 32/32 [==============================] - 46s 1s/step - loss: 0.3695 - accuracy: 0.8957 - val_loss: 0.4723 - val_accuracy: 0.9208
# Epoch 2/100
# 32/32 [==============================] - ETA: 0s - loss: 0.2204 - accuracy: 0.9179

# %%
#After the training is done, we attempt to evaluate our saved networks.

# %%
trained_models=[]
for r,d,f in os.walk('models'):
  for file in f:
    trained_models.append(os.path.join(r,file)) #Add the saved models in the models directory
reports={}
test_df = pd.read_csv("all_test.csv") #Load the full test CSV file that includes 11302 images
validation_generator = test_datagen.flow_from_dataframe( #Set new data generator
        dataframe=test_df,
        directory='All/All',
        x_col="filename",
        y_col="class",
        target_size=(300, 300),
        batch_size=20,
        class_mode='categorical',shuffle=True)
for trained_model in trained_models:
  k.clear_session()
  net=keras.models.load_model(trained_model) #load model
  covid_label= validation_generator.class_indices['COVID-19'] #get the index of COVUD-19 class 
  pneu_label= validation_generator.class_indices['pneumonia'] #get the index of pneumonia class 
  normal_label= validation_generator.class_indices['normal']  #get the index of normal class 
  tp=0 #True Positives
  fp=0 #False Positives
  anum=0 #All the images numbers
  ###########
  wrong_covid=0
  correct_covid=0
  not_detected_covid=0
  covid_num=0
  ###########
  wrong_pneu=0
  correct_pneu=0
  not_detected_pneu=0
  pneu_num=0
  ############
  wrong_normal=0
  correct_normal=0
  not_detected_normal=0
  normal_num=0
  ##############
  wrong_covid_normal=0 #COVID-19 class which has been detected as normal, incorrectly
  wrong_covid_pneu=0   #COVID-19 class which has been detected as pneumonia, incorrectly
  wrong_pneu_covid=0   #pneumonia class which has been detected as COVID-19 , incorrectly
  wrong_pneu_normal=0  #pneumonia class which has been detected as normal , incorrectly
  wrong_normal_pneu=0  #normal class which has been detected as pneumonia , incorrectly
  wrong_normal_covid=0  #normal class which has been detected as COVID-19 , incorrectly
  ################
  for num,img_name in enumerate(validation_generator.filenames): #load image
    gt_ind=validation_generator.classes[num] #get the loaded image class index
    img=cv2.resize(cv2.imread(os.path.join('All','All',img_name)),(300,300)) #resize image
    img=img.astype('float32') / 255.0 #scale the image
    pred_ind=np.argmax(net.predict(np.expand_dims(img,axis=0))[0]) #get the predicted class index

    anum+=1 #count the number of images


    if gt_ind==covid_label:
      covid_num+=1
    if gt_ind==pneu_label:
      pneu_num+=1
    if gt_ind==normal_label:
      normal_num+=1
    ##################
    if gt_ind==covid_label and pred_ind==covid_label: 
      correct_covid+=1
    if gt_ind==covid_label and pred_ind!=covid_label:
      not_detected_covid+=1
      if pred_ind==pneu_label:
        wrong_covid_pneu+=1
      elif pred_ind==normal_label:
        wrong_covid_normal+=1
    if gt_ind!=covid_label and pred_ind==covid_label:
      wrong_covid+=1
    ###########################################
    if gt_ind==normal_label and pred_ind==normal_label: 
      correct_normal+=1
    if gt_ind==normal_label and pred_ind!=normal_label:
      not_detected_normal+=1
      if pred_ind==pneu_label:
        wrong_normal_pneu+=1
      elif pred_ind==covid_label:
        wrong_normal_covid+=1
    if gt_ind!=normal_label and pred_ind==normal_label:
      wrong_normal+=1
    ###########################################
    if gt_ind==pneu_label and pred_ind==pneu_label: 
      correct_pneu+=1
    if gt_ind==pneu_label and pred_ind!=pneu_label:
      not_detected_pneu+=1
      if pred_ind==normal_label:
        wrong_pneu_normal+=1
      elif pred_ind==covid_label:
        wrong_pneu_covid+=1
    if gt_ind!=pneu_label and pred_ind==pneu_label:
      wrong_pneu+=1
    ###########################################

    if pred_ind==gt_ind:
      tp+=1
    else:
      fp+=1

  reports[trained_model[7:]]=[correct_covid,wrong_covid,not_detected_covid,
                   correct_pneu,wrong_pneu,not_detected_pneu,
                   correct_normal,wrong_normal,not_detected_normal,
                   covid_num,pneu_num,normal_num,tp,fp,wrong_covid_normal,wrong_covid_pneu,
                   wrong_pneu_covid,wrong_pneu_normal,wrong_normal_pneu,wrong_normal_covid]


  print(trained_model[7:])
  print('correct_covid: ',correct_covid/covid_num,'%')
  print('wrong_covid: ',wrong_covid)
  print('not_detected_covid: ',not_detected_covid/covid_num,'%')
  print('###########################')

with open('{}-fold{}.csv'.format(trained_model[7:],fold_num),newline='', mode='w') as csvfile: #save the evaluation data into csvfile
     csv_writer = csv.writer(csvfile, delimiter=',', quotechar='"', quoting=csv.QUOTE_MINIMAL)
     csv_writer.writerow(['name','correct_covid','wrong_covid','not_detected_covid',
                          'correct_pneu','wrong_pneu','not_detected_pneu',
                          'correct_normal','wrong_normal','not_detected_normal',
                          'covid_num','pneu_num','normal_num','tp','fp','wrong_covid_normal','wrong_covid_pneu',
                  'wrong_pneu_covid','wrong_pneu_normal','wrong_normal_pneu','wrong_normal_covid'])
     for key in reports.keys():
         row=[key]
         row.extend(reports[key])
